# %%
import numpy as np
import pandas as pd
import seaborn as sns
import cortico_cereb_connectivity.globals as gl
import cortico_cereb_connectivity.run_model as rm
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ##  Evaluate different model fusion

# %%
dff = rm.comb_eval(models=['Fu'])
dff1=rm.comb_eval(models=['Fu04-loo','Fu05-loo','Fu06-loo','Fu07-loo'])
dff = dff[dff['extension']>3]

# %%
# Not cross-validated: 
dff
sns.barplot(data=dff,x='eval_dataset',hue='extension',y='R_eval')
# Out:
# <AxesSubplot:xlabel='eval_dataset', ylabel='R_eval'>

# %%
# Cross-validated:
sns.barplot(data=dff1,x='eval_dataset',hue='extension',y='R_eval')
# Out:
# <AxesSubplot:xlabel='eval_dataset', ylabel='R_eval'>

# %%
def comp_fusion(dff):
    sns.barplot(data=dff,x='extension',y='R_eval')
    t=stats.ttest_rel(dff[dff['extension']==5]['R_eval'],dff[dff['extension']==6]['R_eval']) 
    indx =dff['extension']==5
    df=indx.sum()-1
    print(f't({df}) = {t.statistic:.2f}, p={t.pvalue:.4f}')

# %%
comp_fusion(dff)
# Out:
# t(102) = -3.14, p=0.0022

# %%
comp_fusion(dff1)
# Out:
# t(102) = 0.41, p=0.6795
