# %%
import numpy as np
import pandas as pd
import seaborn as sns
import cortico_cereb_connectivity.globals as gl
import cortico_cereb_connectivity.run_model as rm
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# ##  Evaluate different model fusion

# %%
dff=rm.comb_eval(models=['Fu','Fu06-loo'])

# %%
sns.barplot(data=dff[dff.eval_dataset=='Nishimoto'],x='model',hue='model',y='R_eval')
# Out:
# array(['avg', 'loo'], dtype=object)

# %%
dff
sns.barplot(data=dff[dff.model=='loo'],x='eval_dataset',hue='extension',y='R_eval')
# Out:
# <AxesSubplot:xlabel='eval_dataset', ylabel='R_eval'>

# %%
sns.barplot(data=dff,x='extension',y='R_eval')
# Out:
# <AxesSubplot:xlabel='extension', ylabel='R_eval'>
