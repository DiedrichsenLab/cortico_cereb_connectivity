# %% [markdown]
# ### Here we check individual dataset group models to see whether orbito-frontal weights are caused by a specific dataset or not

# %%
import numpy as np
import pandas as pd
import nibabel as nb
import Functional_Fusion.dataset as fdata # from functional fusion module
import cortico_cereb_connectivity.globals as gl
import cortico_cereb_connectivity.run_model as rm
import cortico_cereb_connectivity.data as cdata
import cortico_cereb_connectivity.cio as cio
import cortico_cereb_connectivity.summarize as cs
import cortico_cereb_connectivity.scripts.script_summarize_weights as cssw
import matplotlib.pyplot as plt
import seaborn as sns
import Functional_Fusion.atlas_map as am
import nitools as nt
import warnings
import SUITPy as suit
from scipy import stats
from statsmodels.stats.multitest import multipletests

# %%
parcellation = 'Icosahedron1002'
method = 'NNLS'
stats_to_calc = 'mean'
la_list = [0, 0, 0, 2, 0, 0, 0, 2, 2]

yeo_img = nb.load(gl.conn_dir + f'/maps/yeo17_{parcellation}.plabel.nii')
yeo_data = yeo_img.get_fdata().squeeze()
label_dict = yeo_img.header.get_axis(0).label[0]
atlas,ainf = am.get_atlas('MNISymC3')

# %%
fig, axes = plt.subplots(np.ceil(len(gl.datasets)/3).astype(int), 3, figsize=(12, 10))
for i, (traindata, ses, la) in enumerate(zip(gl.datasets, gl.sessions, la_list)):
    model, _ = cs.get_model(traindata=f'{traindata}_{ses}', cortex_roi=parcellation,
                            method=method, extension=f'A{la}_group', norm=True)

    project = model.coef_[:, yeo_data==10].mean(axis=1)
    nifti_image = atlas.data_to_nifti(project)
    data = suit.vol_to_surf(nifti_image,space='MNISymC')
    plt.subplot(np.ceil(len(gl.datasets)/3).astype(int), 3, i+1)
    suit.flatmap.plot(data,cmap='hot', new_figure=False)
    axes.flat[i].set_title(traindata, fontsize=11)
plt.suptitle(f'Average Yeo-10 projection to cerebellum', fontsize=16);

# %%
for traindata, ses, la in zip(gl.datasets, gl.sessions, la_list):
    cifti_img = cs.stats_weight_map_cortex(traindata = f"{traindata}_{ses}",
                            cortex_roi = parcellation,
                            method = method,
                            extension = f'A{la}_group',
                            stats = stats_to_calc,
                            norm = True)
    
    fname = f'{traindata}_{parcellation}_{method}_{stats_to_calc}.pscalar.nii'
    nb.save(cifti_img, gl.conn_dir + f'/maps/{fname}')
    # smoothing
    # oname = f'{traindata}_{parcellation}_{method}_{stats_to_calc}.dscalar.nii'
    # cs.pscalar_to_smoothed_dscalar(fname,oname)

    # plot
    cifti_img = nb.load(gl.conn_dir + f'/maps/{fname}')
    data = nt.surf_from_cifti(cifti_img)
    fig, axes = plt.subplots(1, 2, figsize=(10, 4), )#subplot_kw={'projection': '3d'})
    cs.plot_cortical_flatmap(data=data, axes=axes, cmap='hot')
    # cs.plot_cortical_flatmap(data=data, axes=axes, cscale=[0, 1], cmap='hot')
    # cs.plot_cortical_inflated(data=data, axes=axes, cscale=[np.nanmin(data[0])*0.8, np.nanmax(data[0])*1.])
    plt.suptitle(traindata, fontsize=12)
    plt.show()

# %%
names = [label_dict[i+1][0] for i in range(17)]

for traindata, ses, la in zip(gl.datasets, gl.sessions, la_list):
    model,info = cs.get_model(f"{traindata}_{ses}", parcellation, method, f'A{la}_group', norm=True)
    if stats_to_calc == 'mean':
        values = np.mean(model.coef_, axis=0).T
    if stats_to_calc == 'prob':
        values = np.mean(model.coef_>0, axis=0).T
    
    pvals = []
    for i in range(17):
        region_vals = values[yeo_data == i+1]
        other_vals = values[yeo_data != i+1]

        # Mann–Whitney U (region vs others)
        _, p = stats.mannwhitneyu(region_vals, other_vals, alternative="greater")
        pvals.append(p)

    pvals = np.array(pvals).ravel()
    # Multiple comparison correction
    reject, pvals_corr, _, _ = multipletests(pvals, method="fdr_bh")
    pvals_corr_sorted, reject_sorted, names_sorted = zip(*sorted(zip(pvals_corr, reject, names)))

    print("="*35)
    print(f"Dataset {traindata}:")
    print("-"*35)
    print(f'{"Network":<25} {"P_val":<10}')
    for i, (pc, r, name) in enumerate(zip(pvals_corr_sorted, reject_sorted, names_sorted)):
        if r == True:
            if name=='10.LimbicB':
                print(f'\033[1m{name:<25} {pc:<10.2e}\033[0m')
            else:
                print(f'{name:<25} {pc:<10.2e}')
    print("\n")
# Out:
# ===================================
# Dataset MDTB:
# -----------------------------------
# Network                   P_val
# 12.ControlA               3.22e-15
# 06.DorsalAttentionB       3.42e-11
# 17.DefaultB               4.41e-06
# 05.DorsalAttentionA       1.81e-04
# 11.ControlC               8.27e-03
# 13.ControlB               1.88e-02
# 14.TemporalParietal       3.56e-02
#
#
# ===================================
# Dataset WMFS:
# -----------------------------------
# Network                   P_val
# 06.DorsalAttentionB       1.28e-42
# 01.VisualA                1.14e-40
# 05.DorsalAttentionA       4.67e-22
# 03.SomatomotorA           2.97e-08
# 07.VentralAttentionA      3.53e-07
# 12.ControlA               6.45e-05
# 08.VentralAttentionB      9.82e-03
#
#
# ===================================
# Dataset IBC:
# -----------------------------------
# Network                   P_val
# 10.LimbicB                2.30e-15
# 01.VisualA                9.45e-10
# 02.VisualB                9.45e-10
#
#
# ===================================
# Dataset Demand:
# -----------------------------------
# Network                   P_val
# 12.ControlA               1.47e-32
# 01.VisualA                2.03e-19
# 13.ControlB               1.45e-16
# 08.VentralAttentionB      2.49e-13
# 05.DorsalAttentionA       7.75e-09
# 11.ControlC               9.03e-07
# 16.DefaultA               5.82e-03
#
#
# ===================================
# Dataset HCPur100:
# -----------------------------------
# Network                   P_val
# 10.LimbicB                3.86e-23
# 12.ControlA               1.92e-11
# 13.ControlB               5.82e-11
# 05.DorsalAttentionA       2.41e-07
# 01.VisualA                3.35e-05
# 14.TemporalParietal       4.78e-02
#
#
# ===================================
# Dataset Nishimoto:
# -----------------------------------
# Network                   P_val
# 12.ControlA               2.21e-13
# 14.TemporalParietal       4.14e-08
# 10.LimbicB                7.01e-08
# 13.ControlB               1.86e-07
# 09.LimbicA                2.73e-03
#
#
# ===================================
# Dataset Somatotopic:
# -----------------------------------
# Network                   P_val
# 03.SomatomotorA           9.13e-85
# 04.SomatomotorB           8.15e-16
# 06.DorsalAttentionB       8.15e-16
# 02.VisualB                7.64e-10
# 01.VisualA                1.29e-09
# 07.VentralAttentionA      1.51e-05
# 05.DorsalAttentionA       7.09e-05
#
#
# ===================================
# Dataset Social:
# -----------------------------------
# Network                   P_val
# 05.DorsalAttentionA       1.83e-41
# 01.VisualA                3.39e-35
# 12.ControlA               3.94e-30
# 06.DorsalAttentionB       3.47e-16
# 14.TemporalParietal       4.43e-12
#
#
# ===================================
# Dataset Language:
# -----------------------------------
# Network                   P_val
# 06.DorsalAttentionB       1.72e-19
# 01.VisualA                1.59e-10
# 12.ControlA               4.78e-09
# 10.LimbicB                1.73e-08
# 05.DorsalAttentionA       6.41e-05
# 14.TemporalParietal       4.12e-03
