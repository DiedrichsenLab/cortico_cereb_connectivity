# %% [markdown]
# # Estimating connectivity models
# To be provided

# %% [markdown]
# #### Individual model
# Individual models are trained on single subject data. These models are sensitive to the noise on $X$ and $Y$ but can capture individual variation specific to that subject.
#
# To train these models, one should first specify training configuration and model configuration. Then using these two dictionaries, `train_model()` function in `run_model.py` module will run the training process:

# %%
import cortico_cereb_connectivity.run_model as rm

_, conf, train_df = rm.get_train_config(train_dataset='MDTB',
train_ses='all',
train_subjects='all',
run='all',
cond_num='all',
)

# %% [markdown]
# #### Average model

# %% [markdown]
# #### Group model

# %% [markdown]
# #### Global model
