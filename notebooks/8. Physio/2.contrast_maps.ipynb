# %% [markdown]
# ### This notebook loads the f-contrast maps from the RETROICOR regressors and plot them

# %%
import numpy as np
import nibabel as nib
from nilearn import plotting
import os

# %% [markdown]
# #### F-contrast maps of RETROICOR

# %%
fmap_path = '/cifs/diedrichsen/data/Cerebellum/Social/data/GLM_physio/glm_task0_retro1_hr0'
subj_list = ['sub-05']

for sub in subj_list:
    file_path = f'{fmap_path}/{sub}/spmF_0001.nii'
    plotting.plot_glass_brain(file_path, display_mode='lyrz', colorbar=True,
                            plot_abs=False, title=f'{sub}')
    plotting.show()

# %% [markdown]
# #### T-contrast map of HR*CRF

# %%
fmap_path = '/cifs/diedrichsen/data/Cerebellum/Social/data/GLM_physio/glm_task0_retro0_hr1'
subj_list = ['sub-05']

for sub in subj_list:
    file_path = f'{fmap_path}/{sub}/spmT_0001.nii'
    plotting.plot_glass_brain(file_path, display_mode='lyrz', colorbar=True,
                            plot_abs=False, title=f'{sub}')
    plotting.show()

# %% [markdown]
# ### T-contrast map of HR

# %%
fmap_path = '/cifs/diedrichsen/data/Cerebellum/Social/data/GLM_physio/glm_task0_retro0_hr1'
subj_list = ['sub-05']

for sub in subj_list:
    file_path = f'{fmap_path}/{sub}/spmT_0002.nii'
    plotting.plot_glass_brain(file_path, display_mode='lyrz', colorbar=True,
                            plot_abs=False, title=f'{sub}')
    plotting.show()
