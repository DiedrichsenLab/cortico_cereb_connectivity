# %%
import numpy as np
import pandas as pd
import seaborn as sns
import cortico_cereb_connectivity.globals as gl
import cortico_cereb_connectivity.run_model as rm
import Functional_Fusion.dataset as fdata
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# ##  Scaling vs. no-scaling comparison

# %%
df=rm.comb_eval(models=['Md','Ni','Ib','Wm','De','So','Hc'],methods=['L2regression','L2noscale'])

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df[(df.train_dataset!=df.eval_dataset)],x='logalpha',y='R_eval',style='method')
# Out:
# <AxesSubplot:xlabel='logalpha', ylabel='R_eval'>
